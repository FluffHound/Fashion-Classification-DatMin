# %% [markdown]
# <div style='color: lightblue;
#            background-color: black;
#            font-size: 200%;
#            border-radius:15px;
#            text-align:center;
#            font-weight:600;
#            border-style: dashed;
#            border-color: lightblue;
#            font-family: "Verdana";'>
# Import Packages
# <a class="anchor" id="1"></a>

# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns

import cv2
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder

# ML Model
from sklearn.naive_bayes import MultinomialNB

# DL Model
from keras.applications import InceptionV3
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Metrics
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay, accuracy_score

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

sns.palplot(colors_dark)
sns.palplot(colors_green)
sns.palplot(colors_red)

# %% [markdown]
# <div style='color: lightblue;
#            background-color: black;
#            font-size: 200%;
#            border-radius:15px;
#            text-align:center;
#            font-weight:600;
#            border-style: dashed;
#            border-color: lightblue;
#            font-family: "Verdana";'>
# Import Data
# <a class="anchor" id="1"></a>

# %%
labels = ['Bags','Belts','Boots','Dresses','Hats','Jackets & Coats','Jewelry','Knitwear','Loafers',
 'Pants','Sandals','Scarves','Skirt','Sneakers','Sunglasses','T-Shirts']

X = []
y_train = []

image_size = 250 

# All Data
for i in labels:
    folderPath = os.path.join(r"C:\Users\Zagreus\Documents\DUMMY\Dokumen Pribadi\College\Data Mining II\12.1. Scrap Fashion\Dataset",i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size,image_size))
        except:
            print(i, j)
        lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
        img = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)
        X.append(img)
        y_train.append(i)
print('Data train DONE!')

X = np.array(X)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 423/423 [00:02<00:00, 154.07it/s]
# 100%|██████████| 85/85 [00:01<00:00, 57.82it/s]
# 100%|██████████| 112/112 [00:01<00:00, 70.05it/s]
# 100%|██████████| 220/220 [00:06<00:00, 33.68it/s]
# 100%|██████████| 91/91 [00:02<00:00, 34.05it/s]
# 100%|██████████| 381/381 [00:04<00:00, 88.34it/s]
# 100%|██████████| 179/179 [00:00<00:00, 308.44it/s]
# 100%|██████████| 650/650 [00:13<00:00, 48.63it/s]
# 100%|██████████| 99/99 [00:02<00:00, 44.58it/s]
# 100%|██████████| 628/628 [00:13<00:00, 47.45it/s]
# 100%|██████████| 116/116 [00:01<00:00, 62.18it/s]
# 100%|██████████| 80/80 [00:00<00:00, 134.88it/s]
# 100%|██████████| 253/253 [00:07<00:00, 34.75it/s]
# 100%|██████████| 357/357 [00:06<00:00, 53.38it/s]
# 100%|██████████| 216/216 [00:01<00:00, 117.03it/s]
# 100%|██████████| 677/677 [00:10<00:00, 62.58it/s]
# Data train DONE!

# %% [markdown]
# ## Sample Image

# %%
k=0
fig, ax = plt.subplots(1,len(labels),figsize=(25,20))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
             fontname='monospace',y=0.62,x=0.3,alpha=0.8)
for i in labels:
    f=1
    while True :
        if y_train[f]==i:
            ax[k].imshow(X[f])
            ax[k].set_title(y_train[f])
            ax[k].axis('off')
            k+=1
            break
        f+=1

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Split Data

# %%
# split data into Train, Validation and Test
x_train, x_test, y_train, y_test = train_test_split(X, y_train, train_size=0.8, random_state=42)

# %%
X_train = x_train.astype('float32') #set x_train data type as float32
X_test = x_test.astype('float32') #set x_test data type as float32
X_train /= 255 #change x_train value between 0 - 1
X_test /= 255 #change x_test value between 0 - 1

# %%
encoder = OrdinalEncoder()

y_train_ml = encoder.fit_transform(y_train.reshape(-1,1))
y_test_ml = encoder.fit_transform(y_test.reshape(-1,1))

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 3796
# 949

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new.copy()
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new.copy()
y_test = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# ## Data Augmenting

# %%
batch_size=20

train_datagen = ImageDataGenerator(
    rotation_range=30,
    shear_range=0.3,
    zoom_range=0.3,
    width_shift_range=0.1,
    height_shift_range=0.1
)
train_datagen.fit(X_train)
train_generator = train_datagen.flow(
    X_train,
    y_train,
    batch_size=batch_size
)

validation_datagen = ImageDataGenerator()
validation_datagen.fit(X_test)
validation_generator = validation_datagen.flow(
    X_test,
    y_test
)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Machine Learning

# %%
x_train_ml = x_train.reshape(x_train.shape[0], -1)
x_test_ml = x_test.reshape(x_test.shape[0], -1)
# x_train_ml = x_train.flatten()
# x_test_ml = x_test.flatten()

# %%
MNB = MultinomialNB()
MNB.fit(x_train_ml, y_train_ml)
predictions = MNB.predict(x_test_ml)
print(classification_report(y_test_ml, predictions, digits=6))
# Out:
# c:\Users\Zagreus\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#               precision    recall  f1-score   support
#
#          0.0   0.673684  0.609524  0.640000       105
#          1.0   0.171053  0.619048  0.268041        42
#          2.0   0.700000  0.608696  0.651163        23
#          3.0   0.195122  0.363636  0.253968        44
#          4.0   0.250000  0.120000  0.162162        25
#          5.0   0.277027  0.554054  0.369369        74
#          6.0   0.253333  0.926829  0.397906        41
#          7.0   0.500000  0.151786  0.232877       112
#          8.0   0.392857  0.354839  0.372881        31
#          9.0   0.600000  0.295082  0.395604       122
#         10.0   0.285714  0.166667  0.210526        24
#         11.0   0.194444  0.368421  0.254545        19
#         12.0   0.217391  0.333333  0.263158        45
#         13.0   0.166667  0.013699  0.025316        73
#         14.0   0.685714  0.489796  0.571429        49
#         15.0   0.391304  0.066667  0.113924       135
#
#     accuracy                       0.338174       964
#    macro avg   0.372144  0.377630  0.323929       964
# weighted avg   0.414988  0.338174  0.316571       964

# %% [markdown]
# ## Deep Learning

# %% [markdown]
# ### Definisi Model

# %%
input_shape = (250,250,3)

# load base model
inception = InceptionV3(weights='imagenet', input_shape=input_shape, include_top=False)

# %% [markdown]
# ### Arsitektur Model

# %%
# don't train existing weights
for layer in inception.layers:
    layer.trainable = False

inceptionv3 = Sequential()
inceptionv3.add(inception)
inceptionv3.add(Flatten())
#Fully-connected
inceptionv3.add(Dense(256, activation = 'relu'))
inceptionv3.add(BatchNormalization())
inceptionv3.add(Dropout(0.1))
#output mengguunakan softmax
inceptionv3.add(Dense(16, activation='softmax'))

# %% [markdown]
# ### Parameter Model

# %%
# Learning Rate
initial_learning_rate = 1e-3 # 1 x 10^-5

# Learning Rate Scheduler
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=2000,
    decay_rate=0.85,
    staircase=True)

METRICS = ['accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]

inceptionv3.compile(optimizer=tf.keras.optimizers.Adam(lr_schedule),  # Very slow learning rate 
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics='categorical_accuracy')

#callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=4)

# %% [markdown]
# ### Training Model

# %%
# simple early stopping
es = EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1, patience=10)
mc = ModelCheckpoint('12.1. best_model NEW.h5', monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
tf.debugging.set_log_device_placement(True)

epochs_model = 200

inception_history = inceptionv3.fit(train_generator, 
          validation_data=(validation_generator), 
          epochs=epochs_model, 
          batch_size=12,
          callbacks=[es, mc]) 
          
# scores = inceptionv3.evaluate(X_test, y_test, verbose=0)

# print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/200
# 183/183 [==============================] - ETA: 0s - loss: 1.0544 - categorical_accuracy: 0.6846
# Epoch 1: val_categorical_accuracy improved from -inf to 0.79322, saving model to 12.1. best_model NEW.h5
# 183/183 [==============================] - 60s 261ms/step - loss: 1.0544 - categorical_accuracy: 0.6846 - val_loss: 0.5894 - val_categorical_accuracy: 0.7932
# Epoch 2/200
# 183/183 [==============================] - ETA: 0s - loss: 0.6143 - categorical_accuracy: 0.8065
# Epoch 2: val_categorical_accuracy improved from 0.79322 to 0.83042, saving model to 12.1. best_model NEW.h5
# 183/183 [==============================] - 42s 229ms/step - loss: 0.6143 - categorical_accuracy: 0.8065 - val_loss: 0.4861 - val_categorical_accuracy: 0.8304
# Epoch 3/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5525 - categorical_accuracy: 0.8136
# Epoch 3: val_categorical_accuracy improved from 0.83042 to 0.85558, saving model to 12.1. best_model NEW.h5
# 183/183 [==============================] - 43s 234ms/step - loss: 0.5525 - categorical_accuracy: 0.8136 - val_loss: 0.4896 - val_categorical_accuracy: 0.8556
# Epoch 4/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4799 - categorical_accuracy: 0.8456
# Epoch 4: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 43s 232ms/step - loss: 0.4799 - categorical_accuracy: 0.8456 - val_loss: 0.4435 - val_categorical_accuracy: 0.8435
# Epoch 5/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4326 - categorical_accuracy: 0.8483
# Epoch 5: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 44s 238ms/step - loss: 0.4326 - categorical_accuracy: 0.8483 - val_loss: 0.4419 - val_categorical_accuracy: 0.8468
# Epoch 6/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4000 - categorical_accuracy: 0.8653
# Epoch 6: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 46s 251ms/step - loss: 0.4000 - categorical_accuracy: 0.8653 - val_loss: 0.5000 - val_categorical_accuracy: 0.8457
# Epoch 7/200
# 183/183 [==============================] - ETA: 0s - loss: 0.3827 - categorical_accuracy: 0.8689
# Epoch 7: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 45s 247ms/step - loss: 0.3827 - categorical_accuracy: 0.8689 - val_loss: 0.4965 - val_categorical_accuracy: 0.8359
# Epoch 8/200
# 183/183 [==============================] - ETA: 0s - loss: 0.3700 - categorical_accuracy: 0.8700
# Epoch 8: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 41s 224ms/step - loss: 0.3700 - categorical_accuracy: 0.8700 - val_loss: 0.4649 - val_categorical_accuracy: 0.8392
# Epoch 9/200
# 183/183 [==============================] - ETA: 0s - loss: 0.3705 - categorical_accuracy: 0.8776
# Epoch 9: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 41s 225ms/step - loss: 0.3705 - categorical_accuracy: 0.8776 - val_loss: 0.4496 - val_categorical_accuracy: 0.8446
# Epoch 10/200
# 183/183 [==============================] - ETA: 0s - loss: 0.3331 - categorical_accuracy: 0.8858
# Epoch 10: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 42s 229ms/step - loss: 0.3331 - categorical_accuracy: 0.8858 - val_loss: 0.5460 - val_categorical_accuracy: 0.8239
# Epoch 11/200
# 183/183 [==============================] - ETA: 0s - loss: 0.3170 - categorical_accuracy: 0.8894
# Epoch 11: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 43s 236ms/step - loss: 0.3170 - categorical_accuracy: 0.8894 - val_loss: 0.4755 - val_categorical_accuracy: 0.8446
# Epoch 12/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2969 - categorical_accuracy: 0.8952
# Epoch 12: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 45s 245ms/step - loss: 0.2969 - categorical_accuracy: 0.8952 - val_loss: 0.4893 - val_categorical_accuracy: 0.8446
# Epoch 13/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2986 - categorical_accuracy: 0.8960
# Epoch 13: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 44s 238ms/step - loss: 0.2986 - categorical_accuracy: 0.8960 - val_loss: 0.4618 - val_categorical_accuracy: 0.8457
# Epoch 14/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2838 - categorical_accuracy: 0.9028
# Epoch 14: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 42s 231ms/step - loss: 0.2838 - categorical_accuracy: 0.9028 - val_loss: 0.4891 - val_categorical_accuracy: 0.8381
# Epoch 15/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2502 - categorical_accuracy: 0.9149
# Epoch 15: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 42s 230ms/step - loss: 0.2502 - categorical_accuracy: 0.9149 - val_loss: 0.4494 - val_categorical_accuracy: 0.8556
# Epoch 16/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2939 - categorical_accuracy: 0.8927
# Epoch 16: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 43s 232ms/step - loss: 0.2939 - categorical_accuracy: 0.8927 - val_loss: 0.4505 - val_categorical_accuracy: 0.8468
# Epoch 17/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2666 - categorical_accuracy: 0.9031
# Epoch 17: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 43s 232ms/step - loss: 0.2666 - categorical_accuracy: 0.9031 - val_loss: 0.4610 - val_categorical_accuracy: 0.8468
# Epoch 18/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2642 - categorical_accuracy: 0.9097
# Epoch 18: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 42s 232ms/step - loss: 0.2642 - categorical_accuracy: 0.9097 - val_loss: 0.4718 - val_categorical_accuracy: 0.8370
# Epoch 19/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2544 - categorical_accuracy: 0.9129
# Epoch 19: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 43s 237ms/step - loss: 0.2544 - categorical_accuracy: 0.9129 - val_loss: 0.5486 - val_categorical_accuracy: 0.8337
# Epoch 20/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2540 - categorical_accuracy: 0.9067
# Epoch 20: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 42s 232ms/step - loss: 0.2540 - categorical_accuracy: 0.9067 - val_loss: 0.5368 - val_categorical_accuracy: 0.8249
# Epoch 21/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2553 - categorical_accuracy: 0.9102
# Epoch 21: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 43s 233ms/step - loss: 0.2553 - categorical_accuracy: 0.9102 - val_loss: 0.4492 - val_categorical_accuracy: 0.8490
# Epoch 22/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2626 - categorical_accuracy: 0.9050
# Epoch 22: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 43s 233ms/step - loss: 0.2626 - categorical_accuracy: 0.9050 - val_loss: 0.4849 - val_categorical_accuracy: 0.8556
# Epoch 23/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2379 - categorical_accuracy: 0.9195
# Epoch 23: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 43s 232ms/step - loss: 0.2379 - categorical_accuracy: 0.9195 - val_loss: 0.4603 - val_categorical_accuracy: 0.8490
# Epoch 24/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2233 - categorical_accuracy: 0.9217
# Epoch 24: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 45s 247ms/step - loss: 0.2233 - categorical_accuracy: 0.9217 - val_loss: 0.4598 - val_categorical_accuracy: 0.8501
# Epoch 25/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2286 - categorical_accuracy: 0.9179
# Epoch 25: val_categorical_accuracy did not improve from 0.85558
# 183/183 [==============================] - 46s 250ms/step - loss: 0.2286 - categorical_accuracy: 0.9179 - val_loss: 0.4793 - val_categorical_accuracy: 0.8512
# Epoch 26/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2156 - categorical_accuracy: 0.9234
# Epoch 26: val_categorical_accuracy improved from 0.85558 to 0.86105, saving model to 12.1. best_model NEW.h5
# 183/183 [==============================] - 47s 257ms/step - loss: 0.2156 - categorical_accuracy: 0.9234 - val_loss: 0.4385 - val_categorical_accuracy: 0.8611
# Epoch 27/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2278 - categorical_accuracy: 0.9201
# Epoch 27: val_categorical_accuracy did not improve from 0.86105
# 183/183 [==============================] - 43s 237ms/step - loss: 0.2278 - categorical_accuracy: 0.9201 - val_loss: 0.5825 - val_categorical_accuracy: 0.8206
# Epoch 28/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2210 - categorical_accuracy: 0.9212
# Epoch 28: val_categorical_accuracy did not improve from 0.86105
# 183/183 [==============================] - 45s 247ms/step - loss: 0.2210 - categorical_accuracy: 0.9212 - val_loss: 0.5058 - val_categorical_accuracy: 0.8425
# Epoch 29/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2098 - categorical_accuracy: 0.9264
# Epoch 29: val_categorical_accuracy did not improve from 0.86105
# 183/183 [==============================] - 44s 237ms/step - loss: 0.2098 - categorical_accuracy: 0.9264 - val_loss: 0.4415 - val_categorical_accuracy: 0.8545
# Epoch 30/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2174 - categorical_accuracy: 0.9195
# Epoch 30: val_categorical_accuracy did not improve from 0.86105
# 183/183 [==============================] - 43s 235ms/step - loss: 0.2174 - categorical_accuracy: 0.9195 - val_loss: 0.4736 - val_categorical_accuracy: 0.8446
# Epoch 31/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2099 - categorical_accuracy: 0.9272
# Epoch 31: val_categorical_accuracy did not improve from 0.86105
# 183/183 [==============================] - 45s 247ms/step - loss: 0.2099 - categorical_accuracy: 0.9272 - val_loss: 0.4489 - val_categorical_accuracy: 0.8512
# Epoch 32/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2117 - categorical_accuracy: 0.9294
# Epoch 32: val_categorical_accuracy did not improve from 0.86105
# 183/183 [==============================] - 45s 246ms/step - loss: 0.2117 - categorical_accuracy: 0.9294 - val_loss: 0.4496 - val_categorical_accuracy: 0.8468
# Epoch 33/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2107 - categorical_accuracy: 0.9275
# Epoch 33: val_categorical_accuracy did not improve from 0.86105
# 183/183 [==============================] - 43s 237ms/step - loss: 0.2107 - categorical_accuracy: 0.9275 - val_loss: 0.4597 - val_categorical_accuracy: 0.8523
# Epoch 34/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1881 - categorical_accuracy: 0.9359
# Epoch 34: val_categorical_accuracy did not improve from 0.86105
# 183/183 [==============================] - 43s 232ms/step - loss: 0.1881 - categorical_accuracy: 0.9359 - val_loss: 0.4645 - val_categorical_accuracy: 0.8567
# Epoch 35/200
# 183/183 [==============================] - ETA: 0s - loss: 0.2008 - categorical_accuracy: 0.9321
# Epoch 35: val_categorical_accuracy improved from 0.86105 to 0.86761, saving model to 12.1. best_model NEW.h5
# 183/183 [==============================] - 43s 235ms/step - loss: 0.2008 - categorical_accuracy: 0.9321 - val_loss: 0.4261 - val_categorical_accuracy: 0.8676
# Epoch 36/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1778 - categorical_accuracy: 0.9357
# Epoch 36: val_categorical_accuracy did not improve from 0.86761
# 183/183 [==============================] - 44s 242ms/step - loss: 0.1778 - categorical_accuracy: 0.9357 - val_loss: 0.4767 - val_categorical_accuracy: 0.8534
# Epoch 37/200
# 183/183 [==============================] - ETA: 0s - loss: 0.
200
# 183/183 [==============================] - ETA: 0s - loss: 0.1429 - categorical_accuracy: 0.9491
# Epoch 49: val_categorical_accuracy did not improve from 0.86761
# 183/183 [==============================] - 48s 260ms/step - loss: 0.1429 - categorical_accuracy: 0.9491 - val_loss: 0.4898 - val_categorical_accuracy: 0.8578
# Epoch 50/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1620 - categorical_accuracy: 0.9420
# Epoch 50: val_categorical_accuracy did not improve from 0.86761
# 183/183 [==============================] - 47s 254ms/step - loss: 0.1620 - categorical_accuracy: 0.9420 - val_loss: 0.4901 - val_categorical_accuracy: 0.8632
# Epoch 51/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1513 - categorical_accuracy: 0.9455
# Epoch 51: val_categorical_accuracy did not improve from 0.86761
# 183/183 [==============================] - 47s 255ms/step - loss: 0.1513 - categorical_accuracy: 0.9455 - val_loss: 0.4771 - val_categorical_accuracy: 0.8676
# Epoch 52/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1636 - categorical_accuracy: 0.9392
# Epoch 52: val_categorical_accuracy did not improve from 0.86761
# 183/183 [==============================] - 51s 281ms/step - loss: 0.1636 - categorical_accuracy: 0.9392 - val_loss: 0.4713 - val_categorical_accuracy: 0.8654
# Epoch 53/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1510 - categorical_accuracy: 0.9499
# Epoch 53: val_categorical_accuracy did not improve from 0.86761
# 183/183 [==============================] - 47s 259ms/step - loss: 0.1510 - categorical_accuracy: 0.9499 - val_loss: 0.4914 - val_categorical_accuracy: 0.8578
# Epoch 54/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1529 - categorical_accuracy: 0.9483
# Epoch 54: val_categorical_accuracy did not improve from 0.86761
# 183/183 [==============================] - 48s 264ms/step - loss: 0.1529 - categorical_accuracy: 0.9483 - val_loss: 0.4989 - val_categorical_accuracy: 0.8676
# Epoch 55/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1459 - categorical_accuracy: 0.9442
# Epoch 55: val_categorical_accuracy did not improve from 0.86761
# 183/183 [==============================] - 48s 263ms/step - loss: 0.1459 - categorical_accuracy: 0.9442 - val_loss: 0.5013 - val_categorical_accuracy: 0.8643
# Epoch 56/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1416 - categorical_accuracy: 0.9502
# Epoch 56: val_categorical_accuracy did not improve from 0.86761
# 183/183 [==============================] - 43s 236ms/step - loss: 0.1416 - categorical_accuracy: 0.9502 - val_loss: 0.4628 - val_categorical_accuracy: 0.8665
# Epoch 57/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1373 - categorical_accuracy: 0.9510
# Epoch 57: val_categorical_accuracy did not improve from 0.86761
# 183/183 [==============================] - 43s 234ms/step - loss: 0.1373 - categorical_accuracy: 0.9510 - val_loss: 0.4899 - val_categorical_accuracy: 0.8589
# Epoch 58/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1426 - categorical_accuracy: 0.9521
# Epoch 58: val_categorical_accuracy improved from 0.86761 to 0.87199, saving model to 12.1. best_model NEW.h5
# 183/183 [==============================] - 44s 240ms/step - loss: 0.1426 - categorical_accuracy: 0.9521 - val_loss: 0.4841 - val_categorical_accuracy: 0.8720
# Epoch 59/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1378 - categorical_accuracy: 0.9499
# Epoch 59: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 43s 235ms/step - loss: 0.1378 - categorical_accuracy: 0.9499 - val_loss: 0.4576 - val_categorical_accuracy: 0.8709
# Epoch 60/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1310 - categorical_accuracy: 0.9535
# Epoch 60: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 47s 257ms/step - loss: 0.1310 - categorical_accuracy: 0.9535 - val_loss: 0.4447 - val_categorical_accuracy: 0.8698
# Epoch 61/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1254 - categorical_accuracy: 0.9551
# Epoch 61: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 47s 255ms/step - loss: 0.1254 - categorical_accuracy: 0.9551 - val_loss: 0.4587 - val_categorical_accuracy: 0.8709
# Epoch 62/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1370 - categorical_accuracy: 0.9526
# Epoch 62: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 44s 240ms/step - loss: 0.1370 - categorical_accuracy: 0.9526 - val_loss: 0.4806 - val_categorical_accuracy: 0.8621
# Epoch 63/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1370 - categorical_accuracy: 0.9521
# Epoch 63: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 44s 241ms/step - loss: 0.1370 - categorical_accuracy: 0.9521 - val_loss: 0.4857 - val_categorical_accuracy: 0.8687
# Epoch 64/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1262 - categorical_accuracy: 0.9537
# Epoch 64: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 44s 241ms/step - loss: 0.1262 - categorical_accuracy: 0.9537 - val_loss: 0.4814 - val_categorical_accuracy: 0.8665
# Epoch 65/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1178 - categorical_accuracy: 0.9581
# Epoch 65: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 44s 241ms/step - loss: 0.1178 - categorical_accuracy: 0.9581 - val_loss: 0.5188 - val_categorical_accuracy: 0.8534
# Epoch 66/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1280 - categorical_accuracy: 0.9532
# Epoch 66: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 44s 242ms/step - loss: 0.1280 - categorical_accuracy: 0.9532 - val_loss: 0.5023 - val_categorical_accuracy: 0.8621
# Epoch 67/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1154 - categorical_accuracy: 0.9606
# Epoch 67: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 44s 243ms/step - loss: 0.1154 - categorical_accuracy: 0.9606 - val_loss: 0.5081 - val_categorical_accuracy: 0.8611
# Epoch 68/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1265 - categorical_accuracy: 0.9540
# Epoch 68: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 44s 240ms/step - loss: 0.1265 - categorical_accuracy: 0.9540 - val_loss: 0.4724 - val_categorical_accuracy: 0.8643
# Epoch 69/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1259 - categorical_accuracy: 0.9524
# Epoch 69: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 44s 241ms/step - loss: 0.1259 - categorical_accuracy: 0.9524 - val_loss: 0.4973 - val_categorical_accuracy: 0.8709
# Epoch 70/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1315 - categorical_accuracy: 0.9526
# Epoch 70: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 45s 243ms/step - loss: 0.1315 - categorical_accuracy: 0.9526 - val_loss: 0.4990 - val_categorical_accuracy: 0.8643
# Epoch 71/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1218 - categorical_accuracy: 0.9592
# Epoch 71: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 44s 240ms/step - loss: 0.1218 - categorical_accuracy: 0.9592 - val_loss: 0.4924 - val_categorical_accuracy: 0.8600
# Epoch 72/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1301 - categorical_accuracy: 0.9526
# Epoch 72: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 44s 241ms/step - loss: 0.1301 - categorical_accuracy: 0.9526 - val_loss: 0.4927 - val_categorical_accuracy: 0.8698
# Epoch 73/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1238 - categorical_accuracy: 0.9551
# Epoch 73: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 49s 267ms/step - loss: 0.1238 - categorical_accuracy: 0.9551 - val_loss: 0.4896 - val_categorical_accuracy: 0.8720
# Epoch 74/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1278 - categorical_accuracy: 0.9557
# Epoch 74: val_categorical_accuracy did not improve from 0.87199
# 183/183 [==============================] - 46s 253ms/step - loss: 0.1278 - categorical_accuracy: 0.9557 - val_loss: 0.4506 - val_categorical_accuracy: 0.8698
# Epoch 75/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1131 - categorical_accuracy: 0.9606
# Epoch 75: val_categorical_accuracy improved from 0.87199 to 0.87418, saving model to 12.1. best_model NEW.h5
# 183/183 [==============================] - 46s 253ms/step - loss: 0.1131 - categorical_accuracy: 0.9606 - val_loss: 0.4765 - val_categorical_accuracy: 0.8742
# Epoch 76/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1065 - categorical_accuracy: 0.9614
# Epoch 76: val_categorical_accuracy did not improve from 0.87418
# 183/183 [==============================] - 46s 249ms/step - loss: 0.1065 - categorical_accuracy: 0.9614 - val_loss: 0.4865 - val_categorical_accuracy: 0.8654
# Epoch 77/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1074 - categorical_accuracy: 0.9598
# Epoch 77: val_categorical_accuracy did not improve from 0.87418
# 183/183 [==============================] - 46s 248ms/step - loss: 0.1074 - categorical_accuracy: 0.9598 - val_loss: 0.4893 - val_categorical_accuracy: 0.8611
# Epoch 78/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1095 - categorical_accuracy: 0.9578
# Epoch 78: val_categorical_accuracy did not improve from 0.87418
# 183/183 [==============================] - 46s 249ms/step - loss: 0.1095 - categorical_accuracy: 0.9578 - val_loss: 0.4675 - val_categorical_accuracy: 0.8676
# Epoch 79/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1060 - categorical_accuracy: 0.9614
# Epoch 79: val_categorical_accuracy improved from 0.87418 to 0.87746, saving model to 12.1. best_model NEW.h5
# 183/183 [==============================] - 53s 291ms/step - loss: 0.1060 - categorical_accuracy: 0.9614 - val_loss: 0.4754 - val_categorical_accuracy: 0.8775
# Epoch 80/200
# 183/183 [==============================] - ETA: 0s - loss: 0.1135 - categorical_accuracy: 0.9625
# Epoch 80: val_categorical_accuracy improved from 0.87746 to 0.87965, saving model to 12.1. best_model NEW.h5
# 183/183 [==============================] - 46s 251ms/step - loss: 0.1135 - categorical_accuracy: 0.9625 - val_loss: 0.4862 - val_categorical_accuracy: 0.8796
# Epoch 81/200
# 183/183 [==============================] - ETA: 0s - loss: 0.
val_categorical_accuracy did not improve from 0.88074
# 183/183 [==============================] - 47s 257ms/step - loss: 0.0847 - categorical_accuracy: 0.9704 - val_loss: 0.5085 - val_categorical_accuracy: 0.8753
# Epoch 106/200
# 183/183 [==============================] - ETA: 0s - loss: 0.0849 - categorical_accuracy: 0.9696
# Epoch 106: val_categorical_accuracy did not improve from 0.88074
# 183/183 [==============================] - 60s 325ms/step - loss: 0.0849 - categorical_accuracy: 0.9696 - val_loss: 0.4892 - val_categorical_accuracy: 0.8720
# Epoch 106: early stopping

# %% [markdown]
# # Evaluasi Model

# %%
epochs = [i for i in range(106)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = inception_history.history['categorical_accuracy']
train_loss = inception_history.history['loss']
val_acc = inception_history.history['val_categorical_accuracy']
val_loss = inception_history.history['val_loss']

#menampilkan judul
fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold', 
             fontname='monospace',color=colors_dark[1],y=1,x=0.28,alpha=0.8) 

#membuat kurva
sns.despine()
ax[0].plot(epochs, train_acc, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label ='Training Loss')
ax[1].plot(epochs, val_loss, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()
# Out:
# C:\Users\Zagreus\AppData\Local\Temp\ipykernel_17956\3391181491.py:31: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
pred = inceptionv3.predict(X_test)
pred = np.argmax(pred,axis=1)

print(classification_report(y_test_new,pred,target_names=labels, digits=6))
# Out:
# 29/29 [==============================] - 5s 188ms/step
#                  precision    recall  f1-score   support
#
#            Bags   0.978947  0.989362  0.984127        94
#           Belts   0.954545  0.913043  0.933333        23
#           Boots   1.000000  1.000000  1.000000        20
#         Dresses   0.734694  0.782609  0.757895        46
#            Hats   1.000000  1.000000  1.000000        16
# Jackets & Coats   0.822785  0.792683  0.807453        82
#         Jewelry   1.000000  0.973684  0.986667        38
#        Knitwear   0.688889  0.775000  0.729412       120
#         Loafers   0.933333  1.000000  0.965517        14
#           Pants   0.884058  0.890511  0.887273       137
#         Sandals   0.937500  0.937500  0.937500        16
#         Scarves   1.000000  1.000000  1.000000        13
#           Skirt   0.727273  0.769231  0.747664        52
#        Sneakers   1.000000  0.983051  0.991453        59
#      Sunglasses   1.000000  1.000000  1.000000        38
#        T-Shirts   0.906250  0.794521  0.846715       146
#
#        accuracy                       0.871991       914
#       macro avg   0.910517  0.912575  0.910938       914
#    weighted avg   0.876608  0.871991  0.873238       914

# %%
y_hat = inceptionv3.predict(X_test)
# Plot a random sample of 54 test images, their predicted labels and ground truth
figure = plt.figure(figsize= (25, 40))
for i, index in enumerate(np.random.choice(X_test.shape[0], size=70, replace=False)): # size (jumlah total data uji)
    ax = figure.add_subplot(20, 4, i + 1, xticks=[], yticks=[]) #ukuran 10 X 7 untuk visualisasi gambar pada heatmap confusion matrix
    # Display each image
    ax.imshow(np.squeeze(X_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(labels[predict_index], 
                                  labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
plt.show()
# Out:
# 29/29 [==============================] - 5s 187ms/step
